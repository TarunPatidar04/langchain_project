# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.2")

# %%
res=llm.invoke("give me a short poem about the ocean")
res.content
# Out:
# "Here's a short poem about the ocean:\n\nThe ocean's waves crash on the shore,\nA soothing sound that I adore.\nThe salty scent and seaweed's sway,\n Invigorate my senses each day.\n\nThe tides rise high, the tides fall low,\nA constant rhythm, ebb and flow.\nThe ocean's depths, a mystery to share,\nA world of wonder, beyond compare."
