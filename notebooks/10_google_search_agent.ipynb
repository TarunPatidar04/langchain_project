# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langchain.tools import tool

# %%
llm=ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
# llm = ChatGroq(model="openai/gpt-oss-120b")
search=GoogleSerperAPIWrapper()

# %%
# search.run("Address of the White House")
# Out:
# 'The White House 1600 Pennsylvania Avenue, N.W. Washington, D.C. Located at 1600 Pennsylvania Avenue NW in Washington, D.C., Location Washington, D.C., 1600 Pennsylvania Avenue NW Washington, D.C. The White House 1600 Pennsylvania Avenue NW Washington, DC 20500 The White House 1600 Pennsylvania Avenue NW Washington, DC 20500 … 24 hours a day at: Comments: 202-456-1111 Switchboard: 202-456-1414 Fax: 202-456-2461. ... Download the Official White House App • Real-Time News • Live Updates • A Direct Line to the Administration . Trump 45th & 47th President of the United States ... White House, 1600 Pennsylvania Avenue, Northwest, Washington, District of Columbia, DC. Home of the President of the United States, at 202-707-6394, Contact White House online contact form Main address 1600 Pennsylvania Ave., NW Washington, DC 20500 Located at 1600 Pennsylvania Avenue NW in Washington, D.C., it has served as the residence of every U.S. president since John Adams in 1800 when the national ...'

# %%
agent=create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="you are a agent and can search for any question on google"
)

# %%
question="who won the Women's World Cup 2025?"

# %%
response=agent.invoke({"messages":[{"role":"user","content":question}]})

# %%
text = response["messages"][-1].content[0]["text"]

text = text.replace("**", "")
print(text)
# Out:
# In the 2025 ICC Women's Cricket World Cup, India won the tournament, defeating South Africa in the final to claim their first-ever ODI World Cup title.
#
# *(Note: If you are referring to the FIFA Women's World Cup (soccer), the next tournament is scheduled to take place in Brazil in 2027, following Spain's victory in 2023.)*
