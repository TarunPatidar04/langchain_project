# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite",streaming=True)

# %%
question="can you explain me GENAI ?"

# %%
# response=llm.invoke(question)
# print(response.content[0]["text"])

response=llm.stream(question)

# %%
for chunk in response:
    print(chunk.content[0]["text"], end="")


# for chunk in response:
#     try:
#         if not chunk.content:
#             continue

#         for item in chunk.content:
#             if isinstance(item, dict):
#                 text = item.get("text")
#                 if text:
#                     print(text, end="", flush=True)

#     except (AttributeError, IndexError, KeyError, TypeError):
#         continue
# Out:
# **GenAI**, short for **Generative Artificial Intelligence**, is a type of artificial intelligence that can create *new* content—such as text, images, music, audio, and video—based on the prompts and data it has been trained on.
#
# Unlike traditional AI, which is designed to analyze data, recognize patterns, or make predictions (like predicting the weather or recommending a movie), **GenAI actually creates things.**
#
# Here is a breakdown to help you understand it fully:
#
# ---
#
# ### 1. How Does It Work?
# At its core, GenAI relies on **Machine Learning** (specifically, deep learning) and massive amounts of data.
#
# * **Training:** The AI is fed billions of examples of human work (books, websites, art, music, code).
# * **Learning Patterns:** It doesn’t just copy and paste; it learns the *rules* and *patterns* of how things are put together (e.g., how grammar works, what a cat looks like, or how a chord progression sounds).
# * **Generating:** When you give it a **prompt** (an instruction or question), it uses probability to predict what the best response should be, word-by-word or pixel-by-pixel.
#
# ---
#
# ### 2. Common Types of GenAI (With Examples)
# GenAI comes in different forms depending on what you want to create:
#
# * **Text-Generating AI:** Writes essays, emails, code, poems, and translates languages.
#   * *Examples:* OpenAI’s **ChatGPT**, Google’s **Gemini**, Anthropic’s **Claude**.
# * **Image-Generating AI:** Creates realistic photos, paintings, or illustrations from a text description.
#   * *Examples:* **Midjourney**, **DALL-E 3**, **Stable Diffusion**.
# * **Video-Generating AI:** Turns text prompts into short, realistic, or animated video clips.
#   * *Examples:* OpenAI’s **Sora**, **Runway**, **Pika**.
# * **Audio and Music AI:** Generates realistic human voices, sound effects, or full songs in various genres.
#   * *Examples:* **Suno**, **Udio**, **ElevenLabs**.
#
# ---
#
# ### 3. Why is GenAI a Big Deal?
# * **Boosts Productivity:** It can write code in seconds, summarize 100-page reports, or draft emails, saving humans hours of work.
# * **Democratizes Creativity:** You don’t need to know how to paint, code, or play an instrument to bring your ideas to life—you just need to know how to describe them.
# * **Personalization:** It can tailor tutoring, marketing, and entertainment specifically to individual users.
#
# ---
#
# ### 4. What are the Challenges?
# Despite its power, GenAI has major limitations and risks:
# * **"Hallucinations":** GenAI doesn't "know" facts; it predicts words. This means it can confidently give you completely fake or incorrect information.
# * **Bias:** If the training data contains human prejudices or stereotypes, the AI will likely repeat them.
# * **Copyright and Ethics:** GenAI models are trained on vast amounts of human-created art and writing, often without the original creators' permission or compensation.
# * **Deepfakes:** It can be used to create hyper-realistic fake videos or voices of real people, leading to misinformation and fraud.
#
# ### Summary
# Think of Generative AI as a **super-smart, incredibly well-read digital assistant**. It doesn't actually think or feel; instead, it uses massive computing power to predict what you want to see, hear, or read next, and then builds it for you from scratch.
