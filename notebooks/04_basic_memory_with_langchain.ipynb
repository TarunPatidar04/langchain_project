# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")


# res=llm.invoke("Hello i am Tarun")
# print(res.content[0]["text"])

# %%
# res=llm.invoke("who i am")
# print(res.content[0]["text"])
# Out:
# Based on our interaction, you are a user interacting with me—an artificial intelligence developed by Google.
#
# Beyond that, I don't know your name, where you're from, or what you do, because I only know what you share with me in our conversation!
#
# If you want to tell me a bit about yourself, I'm all ears. Otherwise, I'm just here to help you answer questions, brainstorm ideas, or assist with tasks. How can I help you today?

# %%
# prompts=[
#     {"role": "user", "content": "what is my name"},
#     {"role":"ai", "content": "Your name is Tarun."},
#     {"role": "user", "content": "what is my name"},
# ]

# res=llm.invoke(prompts)
# response_text = res.content[0]["text"]
# print(response_text)
# Out:
# Your name is Tarun!

# %% [markdown]
# ## Manage History

# %%
history=[]
while True:
    query=input("Enter your query: ")

    if query.lower() in ["exit", "quit"]:
        print("Good Byeeee...")
        break

    history.append({"role": "user", "content": query})
    print("User : ",query)

    res=llm.invoke(history)
    history.append({"role":"ai", "content": res.content[0]["text"]})
    print("AI : ", res.content[0]["text"][0]["text"], "\n")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# User :  hello
# AI :  [{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': 'El4KXAERTTIPv0dzT2KsUjCb0y2Y/HsLZHTARvKr0lmE8+Zl9Ztx4zX0OQg7q03qToyyn5DYl40ErpC1Q7NxKx3F6Al0LdNQ+ZRJTdLZOzbe9s63euvWegBFqWQucE4J'}}]
#
# User :  i am tarun
# AI :  [{'type': 'text', 'text': 'Hello Tarun! Nice to meet you. How are you doing today?', 'extras': {'signature': 'El4KXAERTTIP/Gma5u5osiv0V8eLhdrL4RgYYOw06ALbpyHYtFDMwGPidCwXtK+7Ow8vd6yRxW2zgVh20CCmqPNCZoGDWTxvETT+D5A0k9U1oTNsOMI/RPVUgwqWjSRd'}}]
#
# User :  how are you
# ...
