# %%
5+5
# Out:
# Running cells with 'env (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/tarun-patidar/Desktop/TechshimLearning_GenAI-Pyhton-Langchain/env/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
### langchain model - OPENAI 
### dotenv
# Out:
# Running cells with 'env (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/tarun-patidar/Desktop/TechshimLearning_GenAI-Pyhton-Langchain/env/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# from dotenv import load_dotenv
# load_dotenv()

# import os
# os.getenv("OPENAI_API_KEY")
#

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model = "gpt-5.6")

# %%
response=llm.invoke("What is the capital of France?")
# response
print(response.content)
