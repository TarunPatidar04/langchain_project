# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Text Docuement Loader

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/speech.txt")
texts=loader.load()
len(texts)
oneDoc=texts[0]
print(oneDoc.page_content)
# Out:
# “My dear friends, students, and respected farmers,
#
# Today, I want to speak from the heart about three pillars that define the future of our nation:
# our youth, our education system, and our farmers.
#
# 🎓 For the Youth
#
# You are the energy that drives our state forward.
# Our commitment is to give you:
# 	•	Skill-based education
# 	•	Digital learning opportunities
# 	•	Better employment pathways
# 	•	Support for innovation, startups, and entrepreneurship
#
# Your dreams are not just your own—they are the dreams of our entire society.
#
# 📚 For Education
#
# Education must not be just a formality; it must be a force of transformation.
# We aim to:
# 	•	Upgrade government schools with smart classrooms
# 	•	Improve teacher training
# 	•	Expand scholarships for higher education
# 	•	Promote technical and vocational courses
# 	•	Ensure every child gets a fair opportunity to learn and grow
#
# Education is the foundation on which we will build tomorrow.
#
# 👨‍🌾 For Farmers
#
# ...

# %% [markdown]
# ## Pdf Document Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("../data/medical_report.pdf")
docs=loader.load()
# print(docs)
len(docs)
# Out:
# 9

# %%
oneDoc=docs[0]
print(oneDoc.page_content)
# Out:
# Report Status
# Female
# 27 Years:
# :
# :
# :
# Age
# Gender
# Reported
# P
# 9/7/2025   4:56:00PM
# DR NITIN NAHAR
# 474764803
# Ms. NIKITA  CHUDHARY:
# :
# :
# :
# :
# Name
# Lab No.
# Ref By
# Collected
# A/c Status
# 10/7/2025  6:31:50PM
# Final
# Collected at            : Processed at             :BHOPAL CC-82
# Mr Rachel V John Pata So Vitus John Mig 26
# Graund,Indrapuri, Phone: 8770817968
#
# LPL - Bhopal Lab II
# Plot No.05, Mandakini Housing Society, Near
# Apurti Shopping Mall, Kolar Main Road,
# Bhopal, M.P. -  462042
# Test Report
# Test Name Results Units Bio. Ref. Interval
# HEMOGRAM
# (SLS Method, Sheath Flow DC Detection Method, Fluorescent Flow Cytometry, Calculated & Capillary Photometry)
# Hemoglobin  12.00 - 15.00 g/dL13.10
# Packed Cell Volume (PCV)  36.00 - 46.00 %39.50
# RBC Count  3.80 - 4.80 mill/mm34.47
# MCV  83.00 - 101.00 fL88.40
# Mentzer Index   19.8
# MCH  27.00 - 32.00 pg29.30
# MCHC  31.50 - 34.50 g/dL33.20
# ...

# %% [markdown]
# ## CSV FIle Loader

# %%
from langchain_community.document_loaders import CSVLoader
loader=CSVLoader("../data/employee_records.csv")
loader
docs=loader.load()
len(docs)
docs[:5]
# Out:
# [Document(metadata={'source': '../data/employee_records.csv', 'row': 0}, page_content='Employee_ID: 1\nEmployee_Name: Daniel Taylor\nAge: 25\nCountry: UK\nDepartment: HR\nPosition: Analyst\nSalary: 142278.32\nJoining_Date: 2023-06-04'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 1}, page_content='Employee_ID: 2\nEmployee_Name: Ethan Brown\nAge: 44\nCountry: India\nDepartment: Marketing\nPosition: Executive\nSalary: 98549.2\nJoining_Date: 2018-01-13'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 2}, page_content='Employee_ID: 3\nEmployee_Name: Sophia Martinez\nAge: 51\nCountry: Japan\nDepartment: Finance\nPosition: Developer\nSalary: 85565.84\nJoining_Date: 2015-04-30'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 3}, page_content='Employee_ID: 4\nEmployee_Name: Ethan Martinez\nAge: 47\nCountry: Germany\nDepartment: Support\nPosition: Analyst\nSalary: 34513.67\nJoining_Date: 2015-06-17'),
# ...

# %% [markdown]
# ## Website Page loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader=WebBaseLoader(web_path="https://techsimplus.com/about-techsimplus")
docs=loader.load()

# %%
docs[0].metadata
# docs[0].page_content
# Out:
# "About Us | TechSimPlusInternshipVector 1.OEventsAbout UsCertificateConnect UsLoginHomeEventsAbout UsInstitute SolutionConnect UsLoginJoin Vector 1.OCopyright 2026 © TechSimPlus - The Symbol of Expertise.Designed by\xa0 Prateek MishraEmpowering Success Through TechnologyUnleashing the Power of TechSimPlus for Next-Level Success.Guiding Students and Professionals to Embrace the Vast Potential of the Tech Industry and Achieve Success in their Journey of Continuous Growth.12k+Trained Students200+Institute Trainings50+TechnologiesInnovation at its Core - Get to Know UsTechSimPlus offer top-quality IT training programs, empowering professionals to excel in a rapidly evolving industry. Our expert instructors, comprehensive courses, and industry-aligned curriculum ensure you acquire the skills needed to succeed in the ever-changing world of technology.Our MissionElevating Lives, Empowering GenerationsOur mission is to provide comprehensive learning and skill-building opportunities that empo
# ...

# %% [markdown]
# ## Wikipedia Loader

# %%
from langchain_community.document_loaders import WikipediaLoader
loader=WikipediaLoader(query="GENAI",load_max_docs=3)
docs=loader.load()

# %%
docs[0].page_content
docs
# Out:
# [Document(metadata={'title': 'Generative AI', 'summary': "Generative artificial intelligence (GenAI) is a subfield of artificial intelligence (AI) that uses generative models to generate text, images, videos, audio, software code or other forms of data. These models learn the underlying patterns and structures of their training data, and use them to generate new data in response to input, which often takes the form of natural language prompts.\nThe prevalence of generative AI tools has increased significantly since the AI boom in the 2020s. This boom was made possible by improvements in deep neural networks, particularly large language models (LLMs), which are based on the transformer architecture. Generative AI applications include chatbots such as ChatGPT, Claude, Microsoft Copilot, DeepSeek, Doubao, Google Gemini, Grok, Kimi and Qwen; text-to-image models such as DALL-E, Firefly, Stable Diffusion, and Midjourney; and text-to-video models such as Veo, LTX and Sora.\nCompanies in a 
# ...
